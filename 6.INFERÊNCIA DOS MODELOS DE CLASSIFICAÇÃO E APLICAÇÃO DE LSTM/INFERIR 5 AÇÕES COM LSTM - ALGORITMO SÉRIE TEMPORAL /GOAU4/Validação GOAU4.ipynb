# %% [markdown]
# # APLICAÇÃO DE UMA REDE NEURAL LSTM --> VALIDAÇÃO: COM DADOS DE TESTE PARA MENSURAR DESEMPENHO

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime
import pandas_datareader.data as web
from sklearn.preprocessing import MinMaxScaler
# Out:
# Using TensorFlow backend.
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Extraindo valores da API Yahoo Finance
#
# Os dados foram extraídos em escala temporal de "semana", no caso 'wk'
#
# Tirando "Date" que era um índice e o colocando como uma coluna normal.
#
# Colocamos Date como a primeira posição entre as colunas.

# %%
start = datetime(2000, 3, 1)
end = datetime(2018, 6, 30)
base = web.get_data_yahoo('GOAU4.SA', start, end, interval = 'wk')

base["Date"] = base.index
base.reset_index(drop=True, inplace=True)


date = base['Date']
base.drop(labels=['Date'], axis=1,inplace = True)
base.insert(0, 'Date', date)

# %%
base.head()
# Out:
#         Date     High      Low     Open    Close  Volume  Adj Close
# 0 2000-05-01  2.13675  1.93062  2.13675  2.06134   399.0   0.966050
# 1 2000-05-08  2.06134  1.86023  2.06134  2.01106   740.0   0.942486
# 2 2000-05-15  2.11161  1.89341  2.01006  1.89341   918.0   0.887349
# 3 2000-05-22  1.91051  1.73454  1.89341  1.87029  1484.0   0.876514
# 4 2000-05-29  2.11161  1.96078  1.98592  2.06134   997.0   0.966050

# %%
base = base.dropna()

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 948 entries, 0 to 947
# Data columns (total 7 columns):
# Date         948 non-null datetime64[ns]
# High         948 non-null float64
# Low          948 non-null float64
# Open         948 non-null float64
# Close        948 non-null float64
# Volume       948 non-null float64
# Adj Close    948 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 59.2 KB

# %% [markdown]
# As variaveis que queremos fazer as previsões, no caso todas as de preço, então coloca-se [:, 1:7], e transformarmos em arrays ao colocar ".values" pois necessitamos normalizar os dados.

# %%
base_train = base.iloc[:, 1:7].values

# %% [markdown]
# # Normalização
#
# Vamos precisar fazer ruma normalização nesses dados, pos quando se trabalha com esse tipo de rede neural, como existem muitas camadas e principalmente o fato de cada camada apontar pra ela mesma para passar informação ele pode ficar bastante lento se for utilizado os valores reais, então vamos aplicar uma normalização para que consigamos colocar esses valores em uma escala de 0 até 1.

# %%
normalizer = MinMaxScaler(feature_range=(0,1))
base_train_normalizer = normalizer.fit_transform(base_train)

# %% [markdown]
# ## No código, queremos prever o preço da ação baseado nos 90 valores anteriores, então irá começar a partir do valor de indice 90
#
# ## Preencher dois vetores, o de previsores e o de preço real
#
# ## previsores: a cada iteração retira do "base_treinamento_normaliza" e vai retirando os preços de 90 em 90, por exemplo, primeiro tira os valores de '0 a 119', depois '1 a 120', '2 a 121'e etc... Sempre assim de 120 em 120, colocando cada grupo desses 120 em cada coluna da variavel previsores
#
# ## preço_real: a cada iteração coloca um valor a partir do indice 120 de "base_treinamento_normalizada'.

# %%
previsores = []
preco_real = []

for i in range(120, 948):
    previsores.append(base_train_normalizer[i-120:i, 0:6])
    preco_real.append(base_train_normalizer[i, 0])
    
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %% [markdown]
# ## Na LSTM tem um formato de input shape, configurada na imagem
#
# ## 'batch_size': Se referindo a quantidade de registros.
#
# ## 'timesteps': Quantos intervalos de tempo, que seriam as colunas, que poderiam ser, por exemplo, t1, t2, t3, cada coluna representa uma unidade do preço da ação no tempo.
#
# ## 'input_dim': Temos 6 indicadores, e com base nesses dados dessa coluna no passado quero prever no futuro. Caso queria utilizar mais atributos previsores pode-se aumentar a dimensionalidade no terceiro item.

# %%
previsores.shape
# Out:
# (828, 120, 6)

# %%
preco_real.shape
# Out:
# (828,)

# %%
input_shape = (previsores.shape[1],6)

# %% [markdown]
# ## Estrutura da Rede Neural
#
# Units equivale a o número de células de memoria, deve ser um número grande pra adicionar mais dimensionalidade e caputar a tendência no decorrer do tempo, se for um valor muito baixo não irá conseguir capturar variação temporal
#
# Return_sequences = utiliza somente quando terá mais de uma camada LSTM, indica irá passar a informação para as próximas camadas subsequentes abaixo a primeira camada
#
# Com esse tipo de rede neural é interessente adicionar mais camdas para ter bons resultados, nesse caso serão 4.
#
# Aqui pode-se reduzir o número de neuronios/células de memória, em alguns casos pode-se colocar valor mais alto nos primeiro e depois dimuir, fazer testes para verificar resultados.
#
# Retira o 'return_sequences', só colocar quando tem mais camadas subsequentes No caso, após, é somente a camada de saída.
#
# Camada de saída, como é apenas a coluna 'close' que estamos predizendo, somente uma unit. Função linear já que é um caso de regressão.

# %%
regressor = Sequential()

regressor.add(LSTM(units = 100, return_sequences = True, input_shape = input_shape))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'linear'))

# %% [markdown]
# RMSprop é um otimizador para RNN.
#
# "mean_squared_error" calculo de erro mais eficiente de calculo do erro.
#
# "mean_absolute_error" como ele faz absoluto fica mais facil entender os resultados.

# %%
regressor.compile(optimizer = 'rmsprop', loss = 'mean_squared_error',
                         metrics = ['mean_absolute_error'])

# %% [markdown]
# # Procesos de treinamento - Interessante rodar PELO MENOS umas 100 epócas se não ele tende a não se adaptar aos dados.

# %%
# %%time
regressor.fit(previsores, preco_real, epochs =100, batch_size = 32 )
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 19:48:20.627470 140450022676288 deprecation_wrapper.py:119] From /home/jarbasjr/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Epoch 1/100
# 828/828 [==============================] - 14s 17ms/step - loss: 0.0219 - mean_absolute_error: 0.1012
# Epoch 2/100
# 828/828 [==============================] - 13s 15ms/step - loss: 0.0112 - mean_absolute_error: 0.0752
# Epoch 3/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0103 - mean_absolute_error: 0.0699
# Epoch 4/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0087 - mean_absolute_error: 0.0625
# Epoch 5/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0077 - mean_absolute_error: 0.0599
# Epoch 6/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0079 - mean_absolute_error: 0.0602
# Epoch 7/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0071 - mean_absolute_error: 0.0557
# Epoch 8/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0065 - mean_absolute_error: 0.0559
# Epoch 9/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0054 - mean_absolute_error: 0.0476
# Epoch 10/100
# 828/828 [==============================] - 20s 24ms/step - loss: 0.0054 - mean_absolute_error: 0.0506
# Epoch 11/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0058 - mean_absolute_error: 0.0517
# Epoch 12/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0054 - mean_absolute_error: 0.0480
# Epoch 13/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0044 - mean_absolute_error: 0.0448
# Epoch 14/100
# 828/828 [==============================] - 19s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.0465
# Epoch 15/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0051 - mean_absolute_error: 0.0483
# Epoch 16/100
# 828/828 [==============================] - 20s 24ms/step - loss: 0.0038 - mean_absolute_error: 0.0414
# Epoch 17/100
# 828/828 [==============================] - 23s 28ms/step - loss: 0.0041 - mean_absolute_error: 0.0425
# Epoch 18/100
# 828/828 [==============================] - 20s 24ms/step - loss: 0.0044 - mean_absolute_error: 0.0437
# Epoch 19/100
# 828/828 [==============================] - 20s 24ms/step - loss: 0.0037 - mean_absolute_error: 0.0411
# Epoch 20/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0035 - mean_absolute_error: 0.0404
# Epoch 21/100
# 828/828 [==============================] - 21s 26ms/step - loss: 0.0039 - mean_absolute_error: 0.0409
# Epoch 22/100
# 828/828 [==============================] - 22s 26ms/step - loss: 0.0038 - mean_absolute_error: 0.0409
# Epoch 23/100
# 828/828 [==============================] - 18s 22ms/step - loss: 0.0033 - mean_absolute_error: 0.0391
# Epoch 24/100
# 828/828 [==============================] - 19s 23ms/step - loss: 0.0039 - mean_absolute_error: 0.0411
# Epoch 25/100
# 828/828 [==============================] - 11s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0391
# Epoch 26/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0378
# Epoch 27/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0380
# Epoch 28/100
# 828/828 [==============================] - 11s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0350
# Epoch 29/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0367
# Epoch 30/100
# 828/828 [==============================] - 10s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0368
# Epoch 31/100
# 828/828 [==============================] - 12s 14ms/step - loss: 0.0029 - mean_absolute_error: 0.0360
# Epoch 32/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0365
# Epoch 33/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0351
# Epoch 34/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0350
# Epoch 35/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0341
# Epoch 36/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0342
# Epoch 37/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0349
# Epoch 38/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0343
# Epoch 39/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0347
# Epoch 40/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0342
# Epoch 41/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0337
# Epoch 42/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0335
# Epoch 43/100
# 828/828 [==============================] - 11s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0337
# Epoch 44/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0341
# Epoch 45/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0343
# Epoch 46/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0332
# Epoch 47/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0302
# Epoch 48/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0327
# Epoch 49/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0321
# Epoch 50/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0325
# Epoch 51/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0312
# Epoch 52/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0308
# Epoch 53/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0345
# Epoch 54/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0315
# Epoch 55/100
# 828/828 [==============================] - 11s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0333
# Epoch 56/100
# 828/828 [==============================] - 9s 11ms/step - loss: 0.0021 - mean_absolute_error: 0.0302
# Epoch 57/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0313
# Epoch 58/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0305
# Epoch 59/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0315
# Epoch 60/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0308
# Epoch 61/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0312
# Epoch 62/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0318
# Epoch 63/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0317
# Epoch 64/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0275
# Epoch 65/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0295
# Epoch 66/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0288
# Epoch 67/100
# 828/828 [==============================] - 11s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0280
# Epoch 68/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0299
# Epoch 69/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0299
# Epoch 70/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0293
# Epoch 71/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0288
# Epoch 72/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0301
# Epoch 73/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0286
# Epoch 74/100
# 828/828 [==============================] - 11s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0284
# Epoch 75/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0295
# Epoch 76/100
# 828/828 [==============================] - 10s 11ms/step - loss: 0.0017 - mean_absolute_error: 0.0274
# Epoch 77/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0299
# Epoch 78/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0287
# Epoch 79/100
# 828/828 [==============================] - 11s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0266
# Epoch 80/100
# 828/828 [==============================] - 10s 11ms/step - loss: 0.0021 - mean_absolute_error: 0.0286
# Epoch 81/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0274
# Epoch 82/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0271
# Epoch 83/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0289
# Epoch 84/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0279
# Epoch 85/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0285
# Epoch 86/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0267
# Epoch 87/100
# 828/828 [==============================] - 10s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0284
# Epoch 88/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0282
# Epoch 89/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0286
# Epoch 90/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0280
# Epoch 91/100
# 828/828 [==============================] - 11s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0275
# Epoch 92/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0260
# Epoch 93/100
# 828/828 [==============================] - 10s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0278
# Epoch 94/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0281
# Epoch 95/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0273
# Epoch 96/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0274
# Epoch 97/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0286
# Epoch 98/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0281
# Epoch 99/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0266
# Epoch 100/100
# 828/828 [==============================] - 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0267
# CPU times: user 25min 8s, sys: 1min 11s, total: 26min 19s
# Wall time: 20min 23s

# %% [markdown]
# # PROCESSO DE TESTE
#
# Agora vamos pegar os dados reais, que ocorreram de fato para comparar em um gráfico visual com o que o modelo treinos de fato.

# %%
start = datetime(2018, 7, 1)
end = datetime(2019, 6, 23)
base_test = web.get_data_yahoo('GOAU4.SA', start, end, interval = 'wk')

base_test["Date"] = base_test.index
base_test.reset_index(drop=True, inplace=True)


date = base_test['Date']
base_test.drop(labels=['Date'], axis=1,inplace = True)
base_test.insert(0, 'Date', date)


base_test.head()
# Out:
#         Date  High   Low  Open  Close      Volume  Adj Close
# 0 2018-07-02  7.04  6.12  6.18   7.01  49299100.0   6.710236
# 1 2018-07-09  7.28  6.75  7.01   7.15  39428000.0   6.844250
# 2 2018-07-16  7.86  7.08  7.18   7.80  83155800.0   7.466455
# 3 2018-07-23  8.09  7.52  7.83   7.87  50977500.0   7.533461
# 4 2018-07-30  8.00  7.50  7.90   7.78  44003000.0   7.447309

# %%
base_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# Date         52 non-null datetime64[ns]
# High         52 non-null float64
# Low          52 non-null float64
# Open         52 non-null float64
# Close        52 non-null float64
# Volume       52 non-null float64
# Adj Close    52 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 3.0 KB

# %% [markdown]
# # Após pegarmos a faixa de data real que corresponde ao que treinamos, pegamos a coluna de interesse, no caso que estamos prevendo.

# %%
preco_real_test = base_test.iloc[:,4:5].values

# %% [markdown]
# Torna-se necessário fazer uma concatenação da base de dados de treinamento(nome "base", que construimos lá em cima) com a base de dados de teste("base_test", que extraímos agora), uma vez que é necessário encontrar os 120 valores anteriores de cada parâmetro da janela deslizante para cada um dos 52 registros de teste.

# %%
full_base = pd.concat([base,base_test])
full_base = full_base.drop('Date', axis = 1)

full_base.head()
# Out:
#       High      Low     Open    Close  Volume  Adj Close
# 0  2.13675  1.93062  2.13675  2.06134   399.0   0.966050
# 1  2.06134  1.86023  2.06134  2.01106   740.0   0.942486
# 2  2.11161  1.89341  2.01006  1.89341   918.0   0.887349
# 3  1.91051  1.73454  1.89341  1.87029  1484.0   0.876514
# 4  2.11161  1.96078  1.98592  2.06134   997.0   0.966050

# %% [markdown]
# Aqui é o momento onde definimos de qual índice será feito a janela deslizante.
#
# Vamos observar.
#
# Temos a base completa, com o base de dados de treinamento concateanda a base de testes. Assim o nosso índice de de interesse será o resultante da base complea menos a base de teste - menos o tamanho da nossa janela deslizante.
#
# Assim teremos o momento exato que a LSTM deverá atuar para predizer a primeira amostra da base de teste, eassim completar os 120 previsores da base de dados de teste.
#
# E ainda colocando os dados na mesma escala. Aqui não chamamos o método '.fit_transform', pq ele vai normalizar as entradas de acordo com o que ja foi normalizado lá na 'base_train_normalizer'.

# %%
entradas = full_base[len(full_base) - len(base_test) - 120:].values
entradas = normalizer.transform(entradas)

# %% [markdown]
# Na variavel 'entradas' pegamos 172 valores, e no 'for' a cada iteração pega um range de 120 valores e coloca em cada coluna primeiro de '0 á 119', '1 á 120' e assim por diante. Até valores de '2 á 121'.
#
# Pegando 52 ranges de 120 valores há 52 linhas de 120 valores de ações, onde cada valor é o 'close' de um dia em sequência.

# %%
X_test = []

for i in range(120,172):
    X_test.append(entradas[i-120:i, 0:6])
    

X_test = np.array(X_test)

# %%
previsoes = regressor.predict(X_test)

# %% [markdown]
# Aqui, devemos normalizar a base de treinamento correspondente a variavel que estamos predizendo, no caso a coluna "close".

# %%
normalizer_previsao = MinMaxScaler(feature_range=(0,1)) 
normalizer_previsao.fit_transform(base_train[:,3:4])
# Out:
# array([[1.88915547e-02],
#        [1.80049370e-02],
#        [1.59303464e-02],
#        [1.55226595e-02],
#        [1.88915547e-02],
#        [1.74729327e-02],
#        [1.50793506e-02],
#        [1.68524075e-02],
#        [1.71183213e-02],
#        [1.95653321e-02],
#        [1.93348594e-02],
#        [1.83595463e-02],
#        [1.71183213e-02],
#        [1.71361302e-02],
#        [1.93348594e-02],
#        [1.93348594e-02],
#        [1.97779917e-02],
#        [2.10192188e-02],
#        [2.12851326e-02],
#        [2.06646095e-02],
#        [1.93348594e-02],
#        [1.88915547e-02],
#        [1.97779917e-02],
#        [1.58418255e-02],
#        [1.57885733e-02],
#        [1.44586488e-02],
#        [1.65686826e-02],
#        [1.44586488e-02],
#        [1.33948147e-02],
#        [1.23309827e-02],
#        [8.66073029e-03],
#        [1.20650667e-02],
#        [1.12671486e-02],
#        [1.08947262e-02],
#        [1.34632338e-01],
#        [1.47778169e-02],
#        [1.40155165e-02],
#        [1.49906531e-02],
#        [1.53452645e-02],
#        [1.29515079e-02],
#        [1.37494261e-02],
#        [6.06594917e-02],
#        [6.66549096e-02],
#        [6.01304892e-02],
#        [6.82419339e-02],
#        [7.14159742e-02],
#        [8.81678663e-02],
#        [7.98800901e-02],
#        [8.02327613e-02],
#        [6.31281981e-02],
#        [6.25991872e-02],
#        [6.71839205e-02],
#        [7.40610120e-02],
#        [8.18197856e-02],
#        [7.97037588e-02],
#        [8.39358125e-02],
#        [8.39358125e-02],
#        [8.21724568e-02],
#        [8.60518394e-02],
#        [8.58755080e-02],
#        [8.99312304e-02],
#        [8.58755080e-02],
#        [8.39358125e-02],
#        [7.12396429e-02],
#        [6.98289499e-02],
#        [6.22465160e-02],
#        [5.55457559e-02],
#        [5.73091116e-02],
#        [6.36572006e-02],
#        [5.73091116e-02],
#        [6.06594917e-02],
#        [6.04831603e-02],
#        [6.08358315e-02],
#        [5.94251469e-02],
#        [6.15411737e-02],
#        [6.10121628e-02],
#        [6.47152141e-02],
#        [7.01816210e-02],
#        [7.49426857e-02],
#        [7.84694055e-02],
#        [7.52953652e-02],
#        [7.40610120e-02],
#        [7.77640633e-02],
#        [7.81167344e-02],
#        [7.75877235e-02],
#        [8.16434459e-02],
#        [8.78151951e-02],
#        [8.78151951e-02],
#        [8.55228369e-02],
#        [7.98800901e-02],
#        [7.58243678e-02],
#        [7.67060498e-02],
#        [8.25251279e-02],
#        [8.12907747e-02],
#        [7.95274190e-02],
#        [7.33556697e-02],
#        [6.66549096e-02],
#        [6.73602519e-02],
#        [7.01816210e-02],
#        [7.19449852e-02],
#        [7.68823812e-02],
#        [8.35831414e-02],
#        [8.34068016e-02],
#        [8.46411548e-02],
#        [9.31052707e-02],
#        [1.03332742e-01],
#        [9.83953463e-02],
#        [1.03685413e-01],
#        [1.05096098e-01],
#        [9.92770199e-02],
#        [1.13736554e-01],
#        [1.22024330e-01],
#        [1.19908303e-01],
#        [1.16028920e-01],
#        [1.12854872e-01],
#        [1.07741136e-01],
#        [1.08446478e-01],
#        [1.13912885e-01],
#        [1.19202961e-01],
#        [1.25022039e-01],
#        [1.22906012e-01],
#        [1.20084643e-01],
#        [1.23611354e-01],
#        [1.24493036e-01],
#        [1.09328160e-01],
#        [1.07388465e-01],
#        [9.69846533e-02],
#        [9.11655752e-02],
#        [9.52212976e-02],
#        [9.15182463e-02]])

# %% [markdown]
# 'Desnormalizando' para visualizar os resultados das previsoes dos preços efetivamente, e compara-los com valores reais.

# %%
previsoes = normalizer_previsao.inverse_transform(previsoes)

# %%
previsoes_mean = previsoes.mean()

# %%
preco_real_test_mean = preco_real_test.mean()

# %% [markdown]
# ### Diferença média entre o preço real e o preço predito.

# %%
Diferença_media = preco_real_test_mean - previsoes_mean
Diferença_media
# Out:
# -0.8029015889534588

# %% [markdown]
# # GRÁFICO COMPARATIVO
#
# Mostrada para um período de 1 ano, ou 52 semanas, que é a escala temporal utilizada.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(preco_real_test, color='red', label='Preço_real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
plt.show()
