# %% [markdown]
# # APLICAÇÃO DE UMA REDE NEURAL LSTM --> PREDICT: SEM DADOS REAIS PARA COMPARAR, MAS BUSCANDO CONVERGIR COM OS RESULTADOS DOS MODELOS DE CLASSIFICAÇÃO SOBRE OS DADOS DE PREÇO E DADOS FUNDAMENTALISTAS.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime
import pandas_datareader.data as web
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jarbasjr/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Extraindo valores da API Yahoo Finance
#
# Os dados foram extraídos em escala temporal de "semana", no caso 'wk'
#
# Tirando "Date" que era um índice e o colocando como uma coluna normal.
#
# Colocamos Date como a primeira posição entre as colunas.

# %%
start = datetime(2000, 3, 1)
end = datetime(2019, 8, 14)
base = web.get_data_yahoo('LAME4.SA', start, end, interval = 'wk')

base["Date"] = base.index
base.reset_index(drop=True, inplace=True)


date = base['Date']
base.drop(labels=['Date'], axis=1,inplace = True)
base.insert(0, 'Date', date)

# %%
base
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2000-02-28  552.594971  481.985992  549.525024  521.895020   5915364.0
# 1   2000-03-06  521.895020  503.475006  521.895020  506.545013   3913716.0
# 2   2000-03-13  546.455017  485.054993  506.545013  497.334991   8767183.0
# 3   2000-03-20  558.120972  491.195007  497.334991  533.560974  10333973.0
# 4   2000-03-27  540.315002  509.614990  533.560974  528.034973   5402331.0
# ..         ...         ...         ...         ...         ...         ...
# 994 2019-07-15   17.610001   16.450001   17.000000   17.170000  21951400.0
# 995 2019-07-22   17.330000   16.650000   17.139999   17.209999  15601600.0
# 996 2019-07-29   19.120001   17.080000   17.080000   18.940001  34218900.0
# 997 2019-08-05   19.459999   17.559999   18.450001   19.190001  35426000.0
# 998 2019-08-12   19.059999   17.410000   18.870001   17.629999  24738500.0
#
#       Adj Close
# 0    481.365631
# 1    467.207642
# 2    458.712830
# 3    492.125610
# 4    487.028656
# ..          ...
# 994   17.170000
# 995   17.209999
# 996   18.940001
# 997   19.190001
# 998   17.629999
#
# [999 rows x 7 columns]

# %%
base = base.dropna()

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 7 columns):
# Date         999 non-null datetime64[ns]
# High         999 non-null float64
# Low          999 non-null float64
# Open         999 non-null float64
# Close        999 non-null float64
# Volume       999 non-null float64
# Adj Close    999 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 62.4 KB

# %% [markdown]
# # Normalização
#
# Vamos precisar fazer ruma normalização nesses dados, pos quando se trabalha com esse tipo de rede neural, como existem muitas camadas e principalmente o fato de cada camada apontar pra ela mesma para passar informação ele pode ficar bastante lento se for utilizado os valores reais, então vamos aplicar uma normalização para que consigamos colocar esses valores em uma escala de 0 até 1.

# %%
base_train = base.iloc[:, 1:7].values

# %%
normalizer = MinMaxScaler(feature_range=(0,1))
base_train_normalizer = normalizer.fit_transform(base_train)

# %% [markdown]
# ## No código, queremos prever o preço da ação baseado nos 90 valores anteriores, então irá começar a partir do valor de indice 90
#
# ## Preencher dois vetores, o de previsores e o de preço real
#
# ## previsores: a cada iteração retira do "base_treinamento_normaliza" e vai retirando os preços de 90 em 90, por exemplo, primeiro tira os valores de '0 a 119', depois '1 a 120', '2 a 121'e etc... Sempre assim de 120 em 120, colocando cada grupo desses 120 em cada coluna da variavel previsores
#
# ## preço_real: a cada iteração coloca um valor a partir do indice 120 de "base_treinamento_normalizada'.

# %%
previsores = []
preco_real = []

for i in range(120, 999):
    previsores.append(base_train_normalizer[i-120:i, 0:6])
    preco_real.append(base_train_normalizer[i, 0])
    
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %% [markdown]
# ## Na LSTM tem um formato de input shape, configurada na imagem
#
# ## 'batch_size': Se referindo a quantidade de registros.
#
# ## 'timesteps': Quantos intervalos de tempo, que seriam as colunas, que poderiam ser, por exemplo, t1, t2, t3, cada coluna representa uma unidade do preço da ação no tempo.
#
# ## 'input_dim': Temos 6 indicadores, e com base nesses dados dessa coluna no passado quero prever no futuro. Caso queria utilizar mais atributos previsores pode-se aumentar a dimensionalidade no terceiro item.

# %%
previsores.shape
# Out:
# (879, 120, 6)

# %%
preco_real.shape
# Out:
# (879,)

# %%
input_shape = (previsores.shape[1],6)

# %% [markdown]
# ## Estrutura da Rede Neural
#
# Units equivale a o número de células de memoria, deve ser um número grande pra adicionar mais dimensionalidade e caputar a tendência no decorrer do tempo, se for um valor muito baixo não irá conseguir capturar variação temporal
#
# Return_sequences = utiliza somente quando terá mais de uma camada LSTM, indica irá passar a informação para as próximas camadas subsequentes abaixo a primeira camada
#
# Com esse tipo de rede neural é interessente adicionar mais camdas para ter bons resultados, nesse caso serão 4.
#
# Aqui pode-se reduzir o número de neuronios/células de memória, em alguns casos pode-se colocar valor mais alto nos primeiro e depois dimuir, fazer testes para verificar resultados.
#
# Retira o 'return_sequences', só colocar quando tem mais camadas subsequentes No caso, após, é somente a camada de saída.
#
# Camada de saída, como é apenas a coluna 'close' que estamos predizendo, somente uma unit. Função linear já que é um caso de regressão.

# %%
regressor = Sequential()

regressor.add(LSTM(units = 100, return_sequences = True, input_shape = input_shape))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'linear'))

# %% [markdown]
# RMSprop é um otimizador para RNN.
#
# "mean_squared_error" calculo de erro mais eficiente de calculo do erro.
#
# "mean_absolute_error" como ele faz absoluto fica mais facil entender os resultados.

# %%
regressor.compile(optimizer = 'rmsprop', loss = 'mean_squared_error',
                         metrics = ['mean_absolute_error'])

# %% [markdown]
# # Procesos de treinamento - Interessante rodar PELO MENOS umas 100 epócas se não ele tende a não se adaptar aos dados.

# %%
# %%time
regressor.fit(previsores, preco_real, epochs =100, batch_size = 32 )
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1116 04:59:37.764711 139878401546048 deprecation_wrapper.py:119] From /home/jarbasjr/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Epoch 1/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0140 - mean_absolute_error: 0.0538
# Epoch 2/100
# 879/879 [==============================] - 26s 29ms/step - loss: 0.0109 - mean_absolute_error: 0.0440
# Epoch 3/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0072 - mean_absolute_error: 0.0364
# Epoch 4/100
# 879/879 [==============================] - 25s 28ms/step - loss: 0.0086 - mean_absolute_error: 0.0382
# Epoch 5/100
# 879/879 [==============================] - 25s 29ms/step - loss: 0.0057 - mean_absolute_error: 0.0327
# Epoch 6/100
# 879/879 [==============================] - 26s 30ms/step - loss: 0.0052 - mean_absolute_error: 0.0332
# Epoch 7/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0057 - mean_absolute_error: 0.0310
# Epoch 8/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0050 - mean_absolute_error: 0.0302
# Epoch 9/100
# 879/879 [==============================] - 30s 34ms/step - loss: 0.0041 - mean_absolute_error: 0.0281
# Epoch 10/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0041 - mean_absolute_error: 0.0290
# Epoch 11/100
# 879/879 [==============================] - 30s 34ms/step - loss: 0.0033 - mean_absolute_error: 0.0268
# Epoch 12/100
# 879/879 [==============================] - 30s 34ms/step - loss: 0.0046 - mean_absolute_error: 0.0318
# Epoch 13/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0043 - mean_absolute_error: 0.0277
# Epoch 14/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0034 - mean_absolute_error: 0.0278
# Epoch 15/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0029 - mean_absolute_error: 0.0266
# Epoch 16/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0033 - mean_absolute_error: 0.0284
# Epoch 17/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0029 - mean_absolute_error: 0.0270
# Epoch 18/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0031 - mean_absolute_error: 0.0268
# Epoch 19/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0025 - mean_absolute_error: 0.0268
# Epoch 20/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0031 - mean_absolute_error: 0.0275
# Epoch 21/100
# 879/879 [==============================] - 29s 33ms/step - loss: 0.0032 - mean_absolute_error: 0.0269
# Epoch 22/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0247
# Epoch 23/100
# 879/879 [==============================] - 28s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0266
# Epoch 24/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0243
# Epoch 25/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0026 - mean_absolute_error: 0.0265
# Epoch 26/100
# 879/879 [==============================] - 25s 29ms/step - loss: 0.0022 - mean_absolute_error: 0.0254
# Epoch 27/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0243
# Epoch 28/100
# 879/879 [==============================] - 28s 31ms/step - loss: 0.0020 - mean_absolute_error: 0.0249
# Epoch 29/100
# 879/879 [==============================] - 29s 34ms/step - loss: 0.0021 - mean_absolute_error: 0.0243
# Epoch 30/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0023 - mean_absolute_error: 0.0258
# Epoch 31/100
# 879/879 [==============================] - 27s 31ms/step - loss: 0.0023 - mean_absolute_error: 0.0242
# Epoch 32/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0020 - mean_absolute_error: 0.0241
# Epoch 33/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0251
# Epoch 34/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0024 - mean_absolute_error: 0.0254
# Epoch 35/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0017 - mean_absolute_error: 0.0233
# Epoch 36/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0026 - mean_absolute_error: 0.0254
# Epoch 37/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0024 - mean_absolute_error: 0.0235
# Epoch 38/100
# 879/879 [==============================] - 25s 28ms/step - loss: 0.0021 - mean_absolute_error: 0.0229
# Epoch 39/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0015 - mean_absolute_error: 0.0222
# Epoch 40/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0020 - mean_absolute_error: 0.0230
# Epoch 41/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0256
# Epoch 42/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0019 - mean_absolute_error: 0.0231
# Epoch 43/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0024 - mean_absolute_error: 0.0228
# Epoch 44/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0020 - mean_absolute_error: 0.0236
# Epoch 45/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0248
# Epoch 46/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0018 - mean_absolute_error: 0.0225
# Epoch 47/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0021 - mean_absolute_error: 0.0231
# Epoch 48/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0015 - mean_absolute_error: 0.0225
# Epoch 49/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0219
# Epoch 50/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0232
# Epoch 51/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0018 - mean_absolute_error: 0.0226
# Epoch 52/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0214
# Epoch 53/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0020 - mean_absolute_error: 0.0231
# Epoch 54/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0018 - mean_absolute_error: 0.0228
# Epoch 55/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0217
# Epoch 56/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0020 - mean_absolute_error: 0.0226
# Epoch 57/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0015 - mean_absolute_error: 0.0220
# Epoch 58/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0222
# Epoch 59/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0018 - mean_absolute_error: 0.0224
# Epoch 60/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0213
# Epoch 61/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0228
# Epoch 62/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0210
# Epoch 63/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0213
# Epoch 64/100
# 879/879 [==============================] - 22s 26ms/step - loss: 0.0016 - mean_absolute_error: 0.0209
# Epoch 65/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0014 - mean_absolute_error: 0.0207
# Epoch 66/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0227
# Epoch 67/100
# 879/879 [==============================] - 25s 28ms/step - loss: 0.0011 - mean_absolute_error: 0.0192
# Epoch 68/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0212
# Epoch 69/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0013 - mean_absolute_error: 0.0214
# Epoch 70/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0197
# Epoch 71/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0012 - mean_absolute_error: 0.0206
# Epoch 72/100
# 879/879 [==============================] - 22s 25ms/step - loss: 0.0012 - mean_absolute_error: 0.0194
# Epoch 73/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0016 - mean_absolute_error: 0.0218
# Epoch 74/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0202
# Epoch 75/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0189
# Epoch 76/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0014 - mean_absolute_error: 0.0217
# Epoch 77/100
# 879/879 [==============================] - 25s 28ms/step - loss: 0.0013 - mean_absolute_error: 0.0201
# Epoch 78/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0194
# Epoch 79/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0199
# Epoch 80/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0212
# Epoch 81/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0196
# Epoch 82/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0193
# Epoch 83/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0197
# Epoch 84/100
# 879/879 [==============================] - 25s 28ms/step - loss: 0.0013 - mean_absolute_error: 0.0212
# Epoch 85/100
# 879/879 [==============================] - 25s 29ms/step - loss: 9.6983e-04 - mean_absolute_error: 0.0185
# Epoch 86/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0196
# Epoch 87/100
# 879/879 [==============================] - 24s 27ms/step - loss: 9.8865e-04 - mean_absolute_error: 0.0178
# Epoch 88/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0011 - mean_absolute_error: 0.0193
# Epoch 89/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0194
# Epoch 90/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0011 - mean_absolute_error: 0.0197
# Epoch 91/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0191
# Epoch 92/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0010 - mean_absolute_error: 0.0182
# Epoch 93/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0011 - mean_absolute_error: 0.0186
# Epoch 94/100
# 879/879 [==============================] - 24s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0195
# Epoch 95/100
# 879/879 [==============================] - 24s 27ms/step - loss: 9.6437e-04 - mean_absolute_error: 0.0180
# Epoch 96/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0013 - mean_absolute_error: 0.0195
# Epoch 97/100
# 879/879 [==============================] - 24s 28ms/step - loss: 0.0016 - mean_absolute_error: 0.0191
# Epoch 98/100
# 879/879 [==============================] - 23s 27ms/step - loss: 0.0011 - mean_absolute_error: 0.0194
# Epoch 99/100
# 879/879 [==============================] - 23s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0181
# Epoch 100/100
# 879/879 [==============================] - 20s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0170
# CPU times: user 27min, sys: 46.7 s, total: 27min 46s
# Wall time: 41min 34s

# %% [markdown]
# # PROCESSO DE TESTE
#
# Tendo como métrica, antes de plotar o gráfico que irá predizer para o futuro.

# %%
start = datetime(2000, 3, 1)
end = datetime(2019, 8, 14)
base_complete = web.get_data_yahoo('LAME4.SA', start, end, interval = 'wk')

base_complete["Date"] = base_complete.index
base_complete.reset_index(drop=True, inplace=True)


date = base_complete['Date']
base_complete.drop(labels=['Date'], axis=1,inplace = True)
base_complete.insert(0, 'Date', date)
base_complete = base_complete.dropna()

base_complete = base_complete.iloc[:, 1:7]
base_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 6 columns):
# High         999 non-null float64
# Low          999 non-null float64
# Open         999 non-null float64
# Close        999 non-null float64
# Volume       999 non-null float64
# Adj Close    999 non-null float64
# dtypes: float64(6)
# memory usage: 54.6 KB

# %% [markdown]
# Aqui é o momento onde definimos de qual índice será feito a janela deslizante.
#
# Vamos observar.
#
# Temos a base completa, com o base de dados de treinamento concateanda a base de testes. Assim o nosso índice de de interesse será o resultante da base complea menos a base de teste - menos o tamanho da nossa janela deslizante.
#
# Assim teremos o momento exato que a LSTM deverá atuar para predizer a primeira amostra da base de teste, eassim completar os 120 previsores da base de dados de teste.
#
# E ainda colocando os dados na mesma escala. Aqui não chamamos o método '.fit_transform', pq ele vai normalizar as entradas de acordo com o que ja foi normalizado lá na 'base_train_normalizer'.

# %%
entradas = base_complete[len(base_complete) - 52 - 120:].values
entradas = normalizer.transform(entradas)
entradas.shape
# Out:
# (172, 6)

# %% [markdown]
# Na variavel 'entradas' pegamos 172 valores, e no 'for' a cada iteração pega um range de 120 valores e coloca em cada coluna primeiro de '0 á 119', '1 á 120' e assim por diante. Até valores de '2 á 121'.
#
# Pegando 52 ranges de 120 valores há 52 linhas de 120 valores de ações, onde cada valor é o 'close' de um dia em sequência.

# %%
X_test = []

for i in range(120,172):
    X_test.append(entradas[i-120:i, 0:6])
    

X_test = np.array(X_test)

# %%
X_test.shape
# Out:
# (52, 120, 6)

# %%
previsoes = regressor.predict(X_test)

# %%
previsoes.shape
# Out:
# (52, 1)

# %% [markdown]
# Aqui, devemos normalizar a base de treinamento correspondente a variavel que estamos predizendo, no caso a coluna "close".

# %%
normalizer_previsao = MinMaxScaler(feature_range=(0,1)) 
normalizer_previsao.fit_transform(base_complete.iloc[:,3:4].values)
# Out:
# array([[4.87281087e-02],
#        [4.72885213e-02],
#        [4.64247672e-02],
#        [4.98221904e-02],
#        [4.93039391e-02],
#        [4.84401906e-02],
#        [4.00906788e-02],
#        [4.00330970e-02],
#        [3.85935096e-02],
#        [3.64629223e-02],
#        [3.43324266e-02],
#        [2.82861619e-02],
#        [2.32764929e-02],
#        [2.74224106e-02],
#        [2.58100718e-02],
#        [3.02440006e-02],
#        [3.00712492e-02],
#        [3.40445086e-02],
#        [3.39869267e-02],
#        [3.24897546e-02],
#        [3.16835880e-02],
#        [2.74224106e-02],
#        [2.83437438e-02],
#        [3.14532519e-02],
#        [2.90923313e-02],
#        [2.85740800e-02],
#        [2.94378312e-02],
#        [2.92650798e-02],
#        [2.84589133e-02],
#        [2.85740800e-02],
#        [2.79982439e-02],
#        [2.85164952e-02],
#        [2.68465745e-02],
#        [2.62131565e-02],
#        [2.52342386e-02],
#        [2.51190720e-02],
#        [2.25854916e-02],
#        [2.17793236e-02],
#        [2.08004043e-02],
#        [1.87849822e-02],
#        [2.16641556e-02],
#        [2.13762389e-02],
#        [1.97639016e-02],
#        [2.02245696e-02],
#        [2.10883209e-02],
#        [2.35068276e-02],
#        [2.52918205e-02],
#        [2.58100718e-02],
#        [2.62707413e-02],
#        [2.77103258e-02],
#        [2.82861619e-02],
#        [2.91499132e-02],
#        [2.82861619e-02],
#        [2.68465745e-02],
#        [2.45433303e-02],
#        [2.10883209e-02],
#        [1.96487349e-02],
#        [1.52148076e-02],
#        [1.64240602e-02],
#        [1.48693062e-02],
#        [1.47542340e-02],
#        [1.45814826e-02],
#        [1.41783979e-02],
#        [1.31418966e-02],
#        [1.08961406e-02],
#        [1.12992253e-02],
#        [1.31418966e-02],
#        [1.22781439e-02],
#        [1.18750592e-02],
#        [1.17598926e-02],
#        [1.21629773e-02],
#        [1.20478106e-02],
#        [1.14143919e-02],
#        [1.12416412e-02],
#        [1.11264746e-02],
#        [1.41208146e-02],
#        [1.21629773e-02],
#        [1.30267286e-02],
#        [1.36025632e-02],
#        [1.28539786e-02],
#        [1.01475552e-02],
#        [1.15871426e-02],
#        [1.22781439e-02],
#        [1.24508939e-02],
#        [1.55603075e-02],
#        [1.61937269e-02],
#        [1.59058089e-02],
#        [1.56178923e-02],
#        [1.64816436e-02],
#        [1.68271449e-02],
#        [1.87849822e-02],
#        [1.85546489e-02],
#        [1.93608169e-02],
#        [2.22975750e-02],
#        [2.28158263e-02],
#        [2.30461596e-02],
#        [2.41978304e-02],
#        [2.74224106e-02],
#        [3.13956700e-02],
#        [2.94378312e-02],
#        [2.82861619e-02],
#        [2.28892423e-04],
#        [1.80905873e-04],
#        [1.42517214e-04],
#        [2.35126270e-05],
#        [3.35897354e-05],
#        [0.00000000e+00],
#        [6.86190450e-05],
#        [8.20555026e-05],
#        [7.14982157e-05],
#        [5.61429444e-05],
#        [8.97336190e-05],
#        [7.53377434e-05],
#        [1.24282750e-04],
#        [8.25356812e-05],
#        [7.29378122e-05],
#        [9.11731931e-05],
#        [8.82940225e-05],
#        [9.45316032e-05],
#        [8.58940913e-05],
#        [8.92534405e-05],
#        [7.58169828e-05],
#        [6.19012857e-05],
#        [4.99053637e-05],
#        [5.37439300e-05],
#        [4.22272474e-05],
#        [1.04608712e-04],
#        [1.08927479e-04],
#        [9.74107739e-05],
#        [1.23323354e-04],
#        [1.80905873e-04],
#        [1.73707958e-04],
#        [2.04898701e-04],
#        [2.14496548e-04],
#        [2.24093500e-04],
#        [2.48086283e-04],
#        [2.09217423e-04],
#        [2.34649825e-04],
#        [2.31291415e-04],
#        [2.37049757e-04],
#        [2.26013230e-04],
#        [2.33690407e-04],
#        [2.17854958e-04],
#        [2.17854958e-04],
#        [2.41368524e-04],
#        [2.70639492e-04],
#        [2.86474942e-04],
#        [3.24863601e-04],
#        [3.27742794e-04],
#        [3.43578243e-04],
#        [3.33501135e-04],
#        [3.12866762e-04],
#        [3.21984452e-04],
#        [3.32541717e-04],
#        [3.35419971e-04],
#        [3.47897010e-04],
#        [3.78127397e-04],
#        [3.87245087e-04],
#        [3.45497079e-04],
#        [3.39259476e-04],
#        [4.04039955e-04],
#        [4.06438947e-04],
#        [4.42428614e-04],
#        [4.64022449e-04],
#        [5.04810100e-04],
#        [5.29763241e-04],
#        [4.95213148e-04],
#        [5.16806984e-04],
#        [5.27843465e-04],
#        [5.00012116e-04],
#        [5.00491333e-04],
#        [4.26593164e-04],
#        [4.17476413e-04],
#        [3.87245087e-04],
#        [4.02120180e-04],
#        [4.18435830e-04],
#        [4.06438947e-04],
#        [4.19395248e-04],
#        [4.47227582e-04],
#        [4.20834823e-04],
#        [3.96842039e-04],
#        [4.10278497e-04],
#        [4.15076481e-04],
#        [3.89644079e-04],
#        [4.02120180e-04],
#        [4.03080537e-04],
#        [3.82446164e-04],
#        [3.73808630e-04],
#        [3.59892955e-04],
#        [3.69489862e-04],
#        [3.97802397e-04],
#        [4.07878566e-04],
#        [4.16036838e-04],
#        [4.31392087e-04],
#        [3.99721188e-04],
#        [3.94923204e-04],
#        [4.34750497e-04],
#        [4.84655883e-04],
#        [5.02411108e-04],
#        [4.68820434e-04],
#        [4.64502606e-04],
#        [4.90414225e-04],
#        [4.78418280e-04],
#        [4.84176666e-04],
#        [4.66901598e-04],
#        [5.25923735e-04],
#        [5.44638333e-04],
#        [5.37920619e-04],
#        [6.12778206e-04],
#        [5.95023920e-04],
#        [6.00782217e-04],
#        [6.60284555e-04],
#        [6.89075322e-04],
#        [6.30053185e-04],
#        [6.18536502e-04],
#        [5.83986455e-04],
#        [5.46558153e-04],
#        [5.37440418e-04],
#        [5.14407053e-04],
#        [5.08169449e-04],
#        [5.17286201e-04],
#        [5.34082052e-04],
#        [5.28802883e-04],
#        [4.96652767e-04],
#        [4.32831706e-04],
#        [3.80527328e-04],
#        [4.15556637e-04],
#        [4.58264063e-04],
#        [4.13157645e-04],
#        [4.21314979e-04],
#        [4.56824489e-04],
#        [4.64022449e-04],
#        [4.22274397e-04],
#        [4.37629690e-04],
#        [4.33791124e-04],
#        [4.31392087e-04],
#        [4.47227582e-04],
#        [4.54425497e-04],
#        [5.26015634e-04],
#        [5.16233945e-04],
#        [4.81998992e-04],
#        [5.22102967e-04],
#        [5.52914800e-04],
#        [5.46067667e-04],
#        [5.08898158e-04],
#        [5.08898158e-04],
#        [5.27971990e-04],
#        [4.67327375e-04],
#        [4.45319076e-04],
#        [4.64881471e-04],
#        [4.68304636e-04],
#        [4.63414708e-04],
#        [4.62436552e-04],
#        [4.87867970e-04],
#        [4.72217303e-04],
#        [5.35307732e-04],
#        [5.30906457e-04],
#        [5.42644547e-04],
#        [4.96671504e-04],
#        [4.77108125e-04],
#        [4.67327375e-04],
#        [5.09876314e-04],
#        [5.12321278e-04],
#        [5.48023978e-04],
#        [4.93736993e-04],
#        [5.28461537e-04],
#        [4.93247446e-04],
#        [4.75641361e-04],
#        [5.29439693e-04],
#        [5.15255789e-04],
#        [5.16233945e-04],
#        [5.08898158e-04],
#        [6.21874297e-04],
#        [5.08898158e-04],
#        [5.16233945e-04],
#        [5.65141454e-04],
#        [5.85683033e-04],
#        [6.18939785e-04],
#        [6.28721520e-04],
#        [6.72248614e-04],
#        [6.61000071e-04],
#        [6.38013573e-04],
#        [6.44860796e-04],
#        [6.09647643e-04],
#        [6.33122750e-04],
#        [6.23830608e-04],
#        [6.42904484e-04],
#        [6.33612342e-04],
#        [6.19917986e-04],
#        [6.50729818e-04],
#        [6.62945203e-04],
#        [6.59193840e-04],
#        [5.49153152e-04],
#        [5.55405691e-04],
#        [5.11014879e-04],
#        [5.19142205e-04],
#        [5.55405691e-04],
#        [5.53530055e-04],
#        [6.11050681e-04],
#        [6.06674673e-04],
#        [6.10426035e-04],
#        [6.10426035e-04],
#        [6.97332113e-04],
#        [7.22969868e-04],
#        [7.14213200e-04],
#        [6.58568300e-04],
#        [6.96081927e-04],
#        [7.01083475e-04],
#        [7.47972692e-04],
#        [7.71737583e-04],
#        [7.63606545e-04],
#        [7.74860633e-04],
#        [8.42385251e-04],
#        [8.84897565e-04],
#        [8.70520516e-04],
#        [8.49887976e-04],
#        [8.46764926e-04],
#        [9.23667996e-04],
#        [9.09909869e-04],
#        [8.51763613e-04],
#        [8.67397466e-04],
#        [8.83650241e-04],
#        [8.53639339e-04],
#        [8.41137927e-04],
#        [8.77394839e-04],
#        [8.56143378e-04],
#        [8.70520516e-04],
#        [8.76147515e-04],
#        [8.99284094e-04],
#        [8.64265114e-04],
#        [7.97997211e-04],
#        [7.29215878e-04],
#        [6.92956104e-04],
#        [7.54228093e-04],
#        [7.07961555e-04],
#        [7.48601094e-04],
#        [7.51105133e-04],
#        [7.79859319e-04],
#        [7.73613309e-04],
#        [7.82991761e-04],
#        [7.69233634e-04],
#        [7.28596957e-04],
#        [7.29215878e-04],
#        [7.55475417e-04],
#        [8.38005486e-04],
#        [8.33006799e-04],
#        [8.15497310e-04],
#        [8.09870310e-04],
#        [8.69892114e-04],
#        [8.73024555e-04],
#        [8.54267652e-04],
#        [8.03624211e-04],
#        [7.49229407e-04],
#        [7.92370123e-04],
#        [7.74232320e-04],
#        [7.76736359e-04],
#        [7.69233634e-04],
#        [7.36099682e-04],
#        [7.64234858e-04],
#        [7.67357907e-04],
#        [7.46725368e-04],
#        [7.26721231e-04],
#        [7.12963104e-04],
#        [7.04210192e-04],
#        [7.01709016e-04],
#        [6.95456387e-04],
#        [6.84202298e-04],
#        [6.73573751e-04],
#        [6.87329105e-04],
#        [6.74823936e-04],
#        [6.97332113e-04],
#        [7.35471280e-04],
#        [8.11126936e-04],
#        [8.53010937e-04],
#        [8.71767840e-04],
#        [8.47383938e-04],
#        [8.28627124e-04],
#        [8.50985221e-04],
#        [8.52542095e-04],
#        [8.61142064e-04],
#        [8.40040593e-04],
#        [8.21283780e-04],
#        [8.91621898e-04],
#        [8.80677270e-04],
#        [9.03344917e-04],
#        [8.90843505e-04],
#        [8.92400290e-04],
#        [9.18978770e-04],
#        [8.93188073e-04],
#        [9.58837055e-04],
#        [9.24446388e-04],
#        [9.23667996e-04],
#        [9.33046358e-04],
#        [9.30701790e-04],
#        [1.02604273e-03],
#        [1.01119675e-03],
#        [9.12723369e-04],
#        [9.47114035e-04],
#        [9.15846329e-04],
#        [8.60363672e-04],
#        [8.50985221e-04],
#        [8.76775917e-04],
#        [8.02526966e-04],
#        [9.25224781e-04],
#        [9.43203202e-04],
#        [1.02448595e-03],
#        [1.12842695e-03],
#        [1.10967004e-03],
#        [1.08075639e-03],
#        [1.00181830e-03],
#        [1.06199957e-03],
#        [1.10107007e-03],
#        [1.10029168e-03],
#        [1.06981185e-03],
#        [1.09482406e-03],
#        [1.06043340e-03],
#        [1.00963049e-03],
#        [9.63526191e-04],
#        [1.00963049e-03],
#        [1.05652256e-03],
#        [1.07293481e-03],
#        [1.05496578e-03],
#        [9.99473732e-04],
#        [1.07215642e-03],
#        [1.01979672e-03],
#        [1.11123631e-03],
#        [1.14249454e-03],
#        [1.10810387e-03],
#        [1.14171614e-03],
#        [1.09325789e-03],
#        [1.14249454e-03],
#        [1.19642041e-03],
#        [1.12999312e-03],
#        [1.05496578e-03],
#        [1.05183343e-03],
#        [1.09169162e-03],
#        [1.11435927e-03],
#        [1.12061467e-03],
#        [1.17062980e-03],
#        [1.20110963e-03],
#        [1.16359601e-03],
#        [1.13468235e-03],
#        [1.12217155e-03],
#        [1.00103991e-03],
#        [9.95562898e-04],
#        [9.78372261e-04],
#        [1.21845974e-03],
#        [1.22971383e-03],
#        [1.21752188e-03],
#        [1.19970284e-03],
#        [1.22221110e-03],
#        [1.22033538e-03],
#        [1.26816532e-03],
#        [1.38164406e-03],
#        [1.30661681e-03],
#        [1.25691123e-03],
#        [1.33006285e-03],
#        [1.38633338e-03],
#        [1.33944130e-03],
#        [1.24847064e-03],
#        [1.28317077e-03],
#        [1.37601706e-03],
#        [1.40884156e-03],
#        [1.39008465e-03],
#        [1.44447946e-03],
#        [1.49981212e-03],
#        [1.54951779e-03],
#        [1.52419603e-03],
#        [1.49793658e-03],
#        [1.56827469e-03],
#        [1.64236408e-03],
#        [1.51106630e-03],
#        [1.62360718e-03],
#        [1.47073908e-03],
#        [1.49981212e-03],
#        [1.48574454e-03],
#        [1.30098981e-03],
#        [1.21564615e-03],
#        [1.27473018e-03],
#        [1.34600616e-03],
#        [1.36288734e-03],
#        [1.43416332e-03],
#        [1.50919057e-03],
#        [1.46604995e-03],
#        [1.51575544e-03],
#        [1.33006285e-03],
#        [1.32443585e-03],
#        [1.22971383e-03],
#        [1.24565714e-03],
#        [1.20157856e-03],
#        [1.14624590e-03],
#        [1.25972473e-03],
#        [1.27097882e-03],
#        [1.38164406e-03],
#        [1.38914679e-03],
#        [1.42759846e-03],
#        [1.42666060e-03],
#        [1.50825271e-03],
#        [1.40133883e-03],
#        [1.47449054e-03],
#        [1.47636608e-03],
#        [1.63110991e-03],
#        [1.60860173e-03],
#        [1.64517767e-03],
#        [1.59078287e-03],
#        [1.63017222e-03],
#        [1.60297473e-03],
#        [1.70519948e-03],
#        [1.69863461e-03],
#        [1.70144802e-03],
#        [1.71176434e-03],
#        [1.69863461e-03],
#        [1.61235318e-03],
#        [1.60485046e-03],
#        [1.62735863e-03],
#        [1.63955050e-03],
#        [1.63298563e-03],
#        [1.35726034e-03],
#        [1.35538461e-03],
#        [1.34881975e-03],
#        [1.21283265e-03],
#        [1.20720556e-03],
#        [1.23065160e-03],
#        [1.25503551e-03],
#        [1.20439206e-03],
#        [1.14999726e-03],
#        [1.19876507e-03],
#        [1.29630050e-03],
#        [1.27379232e-03],
#        [1.29067350e-03],
#        [1.33662771e-03],
#        [1.32724926e-03],
#        [1.34131703e-03],
#        [1.37789279e-03],
#        [1.39289824e-03],
#        [1.39664951e-03],
#        [1.55889624e-03],
#        [1.58234228e-03],
#        [1.43603887e-03]])

# %% [markdown]
# 'Desnormalizando' para visualizar os resultados das previsoes dos preços efetivamente, e compara-los com valores reais.

# %%
previsoes = normalizer_previsao.inverse_transform(previsoes)

# %% [markdown]
# # Gráfico da Predição
#
# Indica que a ação não subiria 10% no próximo 1 ano, ou 52 semanas que é a escala temporal usada.

# %%
plt.plot(previsoes, color = 'blue', label = 'Previsões 52 semanas á partir de 12/08/2019')
plt.title('Previsão preço das ações')
plt.xlabel('Tempo(Semana)')
plt.ylabel('Valor Preço de Fechamento Semanal')
plt.legend()
plt.show()
