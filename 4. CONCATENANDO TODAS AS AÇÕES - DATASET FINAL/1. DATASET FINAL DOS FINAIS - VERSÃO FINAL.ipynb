# %% [markdown]
# # Concatenação de todos os datasets das 39 ações

# %%
import pandas as pd

pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Leitura de todos 39 datasets.

# %%
FINAL_CODE_ABEV3 = pd.read_csv('FINAL_CODE_ABEV3.csv')
FINAL_CODE_B3SA3 = pd.read_csv('FINAL_CODE_B3SA3.csv')
FINAL_CODE_BRFS3 = pd.read_csv('FINAL_CODE_BRFS3.csv')
FINAL_CODE_BRKM5 = pd.read_csv('FINAL_CODE_BRKM5.csv')
FINAL_CODE_BRML3 = pd.read_csv('FINAL_CODE_BRML3.csv')
FINAL_CODE_BTOW3 = pd.read_csv('FINAL_CODE_BTOW3.csv')
FINAL_CODE_CCRO3 = pd.read_csv('FINAL_CODE_CCRO3.csv')
FINAL_CODE_CIEL3 = pd.read_csv('FINAL_CODE_CIEL3.csv')
FINAL_CODE_CMIG4 = pd.read_csv('FINAL_CODE_CMIG4.csv')
FINAL_CODE_CSAN3 = pd.read_csv('FINAL_CODE_CSAN3.csv')
FINAL_CODE_CSNA3 = pd.read_csv('FINAL_CODE_CSNA3.csv')
FINAL_CODE_CYRE3 = pd.read_csv('FINAL_CODE_CYRE3.csv')
FINAL_CODE_ECOR3 = pd.read_csv('FINAL_CODE_ECOR3.csv')
FINAL_CODE_EMBR3 = pd.read_csv('FINAL_CODE_EMBR3.csv')
FINAL_CODE_ENBR3 = pd.read_csv('FINAL_CODE_ENBR3.csv')
FINAL_CODE_EQTL3 = pd.read_csv('FINAL_CODE_EQTL3.csv')
FINAL_CODE_FLRY3 = pd.read_csv('FINAL_CODE_FLRY3.csv')
FINAL_CODE_GGBR4 = pd.read_csv('FINAL_CODE_GGBR4.csv')
FINAL_CODE_GOAU4 = pd.read_csv('FINAL_CODE_GOAU4.csv')
FINAL_CODE_IGTA3 = pd.read_csv('FINAL_CODE_IGTA3.csv')
FINAL_CODE_JBSS3 = pd.read_csv('FINAL_CODE_JBSS3.csv')
FINAL_CODE_LAME4 = pd.read_csv('FINAL_CODE_LAME4.csv')
FINAL_CODE_LREN3 = pd.read_csv('FINAL_CODE_LREN3.csv')
FINAL_CODE_MGLU3 = pd.read_csv('FINAL_CODE_MGLU3.csv')
FINAL_CODE_MRFG3 = pd.read_csv('FINAL_CODE_MRFG3.csv')
FINAL_CODE_MRVE3 = pd.read_csv('FINAL_CODE_MRVE3.csv')
FINAL_CODE_MULT3 = pd.read_csv('FINAL_CODE_MULT3.csv')
FINAL_CODE_NATU3 = pd.read_csv('FINAL_CODE_NATU3.csv')
FINAL_CODE_PCAR4 = pd.read_csv('FINAL_CODE_PCAR4.csv')
FINAL_CODE_PETR3 = pd.read_csv('FINAL_CODE_PETR3.csv')
FINAL_CODE_PETR4 = pd.read_csv('FINAL_CODE_PETR4.csv')
FINAL_CODE_RADL3 = pd.read_csv('FINAL_CODE_RADL3.csv')
FINAL_CODE_RENT3 = pd.read_csv('FINAL_CODE_RENT3.csv')
FINAL_CODE_SBSP3 = pd.read_csv('FINAL_CODE_SBSP3.csv')
FINAL_CODE_TIMP3 = pd.read_csv('FINAL_CODE_TIMP3.csv')
FINAL_CODE_USIM5 = pd.read_csv('FINAL_CODE_USIM5.csv')
FINAL_CODE_VALE3 = pd.read_csv('FINAL_CODE_VALE3.csv')
FINAL_CODE_VIVT4 = pd.read_csv('FINAL_CODE_VIVT4.csv')
FINAL_CODE_WEGE3 = pd.read_csv('FINAL_CODE_WEGE3.csv')

# %% [markdown]
# Concatenação de todos os eles por linhas, como se encaixasse um abaixo do outro.

# %%
supreme_dataset = pd.concat([FINAL_CODE_ABEV3,
                            FINAL_CODE_B3SA3,
                            FINAL_CODE_BRFS3,
                            FINAL_CODE_BRKM5,
                            FINAL_CODE_BRML3,
                            FINAL_CODE_BTOW3,
                            FINAL_CODE_CCRO3,
                            FINAL_CODE_CIEL3,
                            FINAL_CODE_CMIG4,
                            FINAL_CODE_CSAN3,
                            FINAL_CODE_CSNA3,
                            FINAL_CODE_CYRE3,
                            FINAL_CODE_ECOR3,
                            FINAL_CODE_EMBR3,
                            FINAL_CODE_ENBR3,
                            FINAL_CODE_EQTL3,
                            FINAL_CODE_FLRY3,
                            FINAL_CODE_GGBR4,
                            FINAL_CODE_GOAU4,
                            FINAL_CODE_IGTA3,
                            FINAL_CODE_JBSS3,
                            FINAL_CODE_LAME4,
                            FINAL_CODE_LREN3,
                            FINAL_CODE_MGLU3,
                            FINAL_CODE_MRFG3,
                            FINAL_CODE_MRVE3,
                            FINAL_CODE_MULT3,
                            FINAL_CODE_NATU3,
                            FINAL_CODE_PCAR4,
                            FINAL_CODE_PETR3,
                            FINAL_CODE_PETR4,
                            FINAL_CODE_RADL3,
                            FINAL_CODE_RENT3,
                            FINAL_CODE_SBSP3,
                            FINAL_CODE_TIMP3,
                            FINAL_CODE_USIM5,
                            FINAL_CODE_VALE3,
                            FINAL_CODE_VIVT4,
                            FINAL_CODE_WEGE3], sort = False)

supreme_dataset.head()
# Out:
#   Quarter  Year  Cluster_Month target       High      Low       Open      Close        Volume  Adj Close  Ativo Total  Ativo Circulante  Caixa e Equivalentes de Caixa AC  Aplicações Financeiras AC  Contas a Receber AC  Estoques AC  Ativos Biológicos AC  Tributos a Recuperar AC  Despesas Antecipadas AC  Outros Ativos Circulantes AC  Ativo Realizavel Longo Prazo  Aplicações Financeiras Avaliadas a Valor Justo ACLP  Aplicações Financeiras Avaliadas ao Custo Amortizado ACLP  Contas a Receber ACLP  Estoques ACLP  Ativos Biológicos ACLP  Tributos Diferidos ACLP  Despesas Antecipadas ACLP  Créditos com Partes Relacionadas ACLP  Outros Ativos Não Circulantes ACLP  Investimentos  Imobilizado  Intangível  Diferido  Passivo Total  Passivo Circulante  Obrigações Sociais e Trabalhistas PC  Fornecedores PC  Obrigações Fiscais PC  Empréstimos e Financiamentos PC  Passivos com Partes Relacionadas PC  Dividendos e JCP a Pagar PC  Outros PC  Provisões PC  \
# ...

# %%
supreme_dataset.shape
# Out:
# (1392, 66)

# %% [markdown]
# Retriramos a última coluna que havia muitos valores NaN.

# %%
supreme_dataset = supreme_dataset.iloc[0:,0:65]
supreme_dataset.head()
# Out:
#   Quarter  Year  Cluster_Month target       High      Low       Open      Close        Volume  Adj Close  Ativo Total  Ativo Circulante  Caixa e Equivalentes de Caixa AC  Aplicações Financeiras AC  Contas a Receber AC  Estoques AC  Ativos Biológicos AC  Tributos a Recuperar AC  Despesas Antecipadas AC  Outros Ativos Circulantes AC  Ativo Realizavel Longo Prazo  Aplicações Financeiras Avaliadas a Valor Justo ACLP  Aplicações Financeiras Avaliadas ao Custo Amortizado ACLP  Contas a Receber ACLP  Estoques ACLP  Ativos Biológicos ACLP  Tributos Diferidos ACLP  Despesas Antecipadas ACLP  Créditos com Partes Relacionadas ACLP  Outros Ativos Não Circulantes ACLP  Investimentos  Imobilizado  Intangível  Diferido  Passivo Total  Passivo Circulante  Obrigações Sociais e Trabalhistas PC  Fornecedores PC  Obrigações Fiscais PC  Empréstimos e Financiamentos PC  Passivos com Partes Relacionadas PC  Dividendos e JCP a Pagar PC  Outros PC  Provisões PC  \
# ...

# %% [markdown]
# # Informação do dataset concatenado, que será feita limpeza e preenchimento de dados faltantes no próximo notebook.

# %%
supreme_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1392 entries, 0 to 37
# Data columns (total 65 columns):
# Quarter                                                             1392 non-null object
# Year                                                                1392 non-null int64
# Cluster_Month                                                       1392 non-null int64
# target                                                              1390 non-null object
# High                                                                1392 non-null float64
# Low                                                                 1392 non-null float64
# Open                                                                1392 non-null float64
# Close                                                               1392 non-null float64
# Volume                                                              1392 non-null float64
# ...

# %%
supreme_dataset.to_csv("FINAL'S_DATASET'S_CONCATENADOS.csv", index= False)

# %%
supreme_dataset.head()
# Out:
#   Quarter  Year  Cluster_Month target       High      Low       Open      Close        Volume  Adj Close  Ativo Total  Ativo Circulante  Caixa e Equivalentes de Caixa AC  Aplicações Financeiras AC  Contas a Receber AC  Estoques AC  Ativos Biológicos AC  Tributos a Recuperar AC  Despesas Antecipadas AC  Outros Ativos Circulantes AC  Ativo Realizavel Longo Prazo  Aplicações Financeiras Avaliadas a Valor Justo ACLP  Aplicações Financeiras Avaliadas ao Custo Amortizado ACLP  Contas a Receber ACLP  Estoques ACLP  Ativos Biológicos ACLP  Tributos Diferidos ACLP  Despesas Antecipadas ACLP  Créditos com Partes Relacionadas ACLP  Outros Ativos Não Circulantes ACLP  Investimentos  Imobilizado  Intangível  Diferido  Passivo Total  Passivo Circulante  Obrigações Sociais e Trabalhistas PC  Fornecedores PC  Obrigações Fiscais PC  Empréstimos e Financiamentos PC  Passivos com Partes Relacionadas PC  Dividendos e JCP a Pagar PC  Outros PC  Provisões PC  \
# ...
